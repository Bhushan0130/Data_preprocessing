# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Numerical Missing Value Imputation By Class

# %%
# imputation by group can not perform every time, its depends upon data. which kind of data we have.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'https://raw.githubusercontent.com/Bhushan0130/Pratice_project/main/houseprice_train.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_columns', None)
pd.set_option ('display.max_rows', None)

# %%
df.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
missing_value_clm_gre_20 = ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'] # carried out by last programe
df2 = df.drop(columns = missing_value_clm_gre_20)
df2.shape
# Out:
# (1460, 76)

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# 1stFlrSF           0
# ...

# %%
numeric_df = df2.select_dtypes(include = ['int', 'float'])
numeric_df.shape
# Out:
# (1460, 38)

# %%
numeric_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
miss_numeric_col = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea' ]

df2[miss_numeric_col][ df2[miss_numeric_col].isnull().any(axis = 1)  ]
# Out:
#       LotFrontage  GarageYrBlt  MasVnrArea
# 7             NaN       1973.0       240.0
# 12            NaN       1962.0         0.0
# 14            NaN       1960.0       212.0
# 16            NaN       1970.0       180.0
# 24            NaN       1968.0         0.0
# 31            NaN       1966.0         0.0
# 39           65.0          NaN         0.0
# 42            NaN       1983.0         0.0
# 43            NaN       1977.0         0.0
# 48           33.0          NaN         0.0
# 50            NaN       1997.0         0.0
# 64            NaN       1998.0       573.0
# 66            NaN       1970.0       287.0
# 76            NaN       1956.0         0.0
# 78           72.0          NaN         0.0
# 84            NaN       1995.0        22.0
# 88          105.0          NaN         0.0
# 89           60.0          NaN         0.0
# 95            NaN       1993.0        68.0
# 99           77.0          NaN         0.0
# 100           NaN       1977.0        28.0
# ...

# %%
df2.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
#
# ...

# %%
df2['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
df2[df2.loc[:, 'LotConfig'] == 'Inside']['LotFrontage'].replace(np.nan, df2[df2.loc[:, 'LotConfig'] == 'Inside']['LotFrontage'].mean())
# Out:
# 0        65.000000
# 2        68.000000
# 5        85.000000
# 6        75.000000
# 8        51.000000
# 10       70.000000
# 11       85.000000
# 12       67.715686
# 13       91.000000
# 17       72.000000
# 18       66.000000
# 19       70.000000
# 21       57.000000
# 22       75.000000
# 23       44.000000
# 24       67.715686
# 27       98.000000
# 29       60.000000
# 30       50.000000
# 33       70.000000
# 34       60.000000
# 35      108.000000
# 37       74.000000
# 38       68.000000
# 39       65.000000
# 40       84.000000
# 41      115.000000
# 44       70.000000
# 45       61.000000
# 47       84.000000
# 48       33.000000
# 49       66.000000
# 51       52.000000
# 53       68.000000
# 54       60.000000
# 55      100.000000
# 56       24.000000
# 59       60.000000
# 60       63.000000
# 61       60.000000
# 62       44.000000
# 63       50.000000
# 64       67.715686
# 65       76.000000
# 66       67.715686
# 67       72.000000
# 70       95.000000
# ...

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         8
# MasVnrArea         8
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinSF1         0
# BsmtFinType2      38
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# 1stFlrSF           0
# ...

# %%
df_copy = df2.copy()

for var in df2['LotConfig'].unique():
    
    df_copy.update (df2[df2.loc[:, 'LotConfig'] == var]['LotFrontage'].replace(np.nan, df2[df2.loc[:, 'LotConfig'] == var]['LotFrontage'].mean()))

# %%
df_copy.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage       0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinSF1        0
# BsmtFinType2     38
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# ...

# %%
miss_numeric_col = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea' ] 
ref_cat = ['LotConfig','GarageType',  'MasVnrType', ]

for col, ref in zip(miss_numeric_col, ref_cat) :
    for var_class in df2[ref].unique( ):
            df_copy.update (df2[df2.loc[:, ref] == var_class][col].replace(np.nan, df2[df2.loc[:, ref] == var_class][col].mean()))

# %%
df_copy[miss_numeric_col].isnull().sum()  # becauses GarageType and MasVnrType have null values too
# we have to make sure our ref varaible should be clean, not null value should be present there.
# Out:
# LotFrontage     0
# GarageYrBlt    81
# MasVnrArea      8
# dtype: int64

# %%
df_copy[df_copy[['GarageType']].isnull().any(axis = 1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 39      40          90       RL    65.000000     6040   Pave      Reg
# 48      49         190       RM    33.000000     4456   Pave      Reg
# 78      79          90       RL    72.000000    10778   Pave      Reg
# 88      89          50  C (all)   105.000000     8470   Pave      IR1
# 89      90          20       RL    60.000000     8070   Pave      Reg
# 99     100          20       RL    77.000000     9320   Pave      IR1
# 108    109          50       RM    85.000000     8500   Pave      Reg
# 125    126         190       RM    60.000000     6780   Pave      Reg
# 127    128          45       RM    55.000000     4388   Pave      IR1
# 140    141          20       RL    70.000000    10500   Pave      Reg
# 148    149          20       RL    63.000000     7500   Pave      Reg
# 155    156          50       RL    60.000000     9600   Pave      Reg
# ...

# %%
df_copy[df_copy[['MasVnrType']].isnull().any(axis = 1)]  # we can see 'MarVnrType' variable have already some nan values
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 234    235          60       RL    67.715686     7851   Pave      Reg
# 529    530          20       RL    59.911111    32668   Pave      IR1
# 650    651          60       FV    65.000000     8125   Pave      Reg
# 936    937          20       RL    67.000000    10083   Pave      Reg
# 973    974          20       FV    95.000000    11639   Pave      Reg
# 977    978         120       FV    35.000000     4274   Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave      Reg
# 1278  1279          60       RL    75.000000     9473   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# 650          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# ...

# %%
miss_numeric_col = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea' ] 
ref_cat = ['LotConfig','KitchenQual',  'Exterior2nd', ]

for col, ref in zip(miss_numeric_col, ref_cat) :
    for var_class in df2[ref].unique( ):
            df_copy.update (df2[df2.loc[:, ref] == var_class][col].replace(np.nan, df2[df2.loc[:, ref] == var_class][col].mean()))

# %%
df_copy[miss_numeric_col].isnull().sum()
# Out:
# LotFrontage    0
# GarageYrBlt    0
# MasVnrArea     0
# dtype: int64

# %%
# Distribution pLot

# %%
import warnings
warnings.filterwarnings('ignore')


plt.figure(figsize = (25, 25))
sns.set()

for i, var in enumerate(miss_numeric_col):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'red' }, label = "Original")
    sns.distplot(df_copy[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'green' }, label = 'Mean')
    plt.legend()

# %% [markdown]
# # for median

# %%
df_copy2 = df2.copy()
miss_numeric_col = ['LotFrontage', 'GarageYrBlt', 'MasVnrArea' ] 
ref_cat = ['LotConfig','KitchenQual',  'Exterior2nd', ]

for col, ref in zip(miss_numeric_col, ref_cat) :
    for var_class in df2[ref].unique( ):
            df_copy2.update (df2[df2.loc[:, ref] == var_class][col].replace(np.nan, df2[df2.loc[:, ref] == var_class][col].median()))

# %%
for i, var in enumerate(miss_numeric_col):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'red' }, label = "Original")
    sns.distplot(df_copy2[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'green' }, label = 'Median')
    plt.legend()

# %%
df_copy2[miss_numeric_col].isnull().sum()
# Out:
# LotFrontage    0
# GarageYrBlt    0
# MasVnrArea     0
# dtype: int64

# %%
plt.figure(figsize = (25, 25))
sns.set()

for i, var in enumerate(miss_numeric_col):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'red' }, label = "Original")
    sns.distplot(df_copy[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'green' }, label = 'Mean')
    sns.distplot(df_copy2[var], bins = 20, kde_kws = {'linewidth' : 5, 'color' : 'k' }, label = 'Median')
    
    plt.legend()

# %%
# Boxplot for outlier

# %%
for i , var in enumerate (miss_numeric_col):
    plt.figure(figsize = (10, 10))
    plt.subplot(3,1,1)
    sns.boxplot(df2[var])
    

    plt.subplot(3,1,2)
    sns.boxplot(df_copy[var])
    
    plt.subplot(3,1,3)
    sns.boxplot(df_copy2[var])
